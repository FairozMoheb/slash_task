# %%
import pandas as  pd
import matplotlib.pyplot as plt

# %%
report = pd.read_csv("amazon_sales_report.csv", encoding="latin-1")
report.head()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_12764\3074351273.py:1: DtypeWarning: Columns (21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   report = pd.read_csv("amazon_sales_report.csv", encoding="latin-1")
#    index             Order ID      Date                        Status  \
# 0    0.0  405-8078784-5731545  04-30-22                     Cancelled
# 1    1.0  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2    2.0  404-0687676-7273146  04-30-22                       Shipped
# 3    3.0  403-9615377-8133951  04-30-22                     Cancelled
# 4    4.0  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# 0            Set  ...      INR  647.62       MUMBAI  MAHARASHTRA
# 1          kurta  ...      INR  406.00    BENGALURU    KARNATAKA
# 2          kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA
# 3  Western Dress  ...      INR  753.33   PUDUCHERRY   PUDUCHERRY
# 4            Top  ...      INR  574.00      CHENNAI   TAMIL NADU
#
#   ship-postal-code  ship-country  \
# 0         400081.0            IN
# 1         560085.0            IN
# 2         410210.0            IN
# 3         605008.0            IN
# 4         600073.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 0                                                NaN  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
# 3                                                NaN  False     Easy Ship
# 4                                                NaN  False           NaN
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 24 columns]

# %%
report.dtypes
# Out:
# index                 float64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                   float64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                    object
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object

# %%
#summary statistics for numerical variables
report.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128940.000000
# mean    64487.000000       0.904431     648.561465     463969.927594
# std     37232.019822       0.313354     281.211687     191475.956294
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
#summary statistics for numerical variables
report.describe(include=['object'])
# Out:
#                    Order ID      Date   Status Fulfilment Sales Channel   \
# count                128977    128977   128977     128977         128977
# unique               120379        92       14          4              3
# top     403-4984515-8861958  05-03-22  Shipped     Amazon      Amazon.in
# freq                     12      2085    77804      89698         128851
#
#        ship-service-level    Style           SKU Category    Size        ASIN  \
# count              128977   128977        128975   128975  128975      128975
# unique                  3     1378          7195        9      11        7190
# top             Expedited  JNE3797  JNE3797-KR-L      Set       M  B09SDXFFQ1
# freq                88615     4224           773    50284   22711         773
#
#        Courier Status currency  ship-city   ship-state ship-country  \
# count          122103   121180     128942       128940       128940
# unique              3        1       8955           69            1
# top           Shipped      INR  BENGALURU  MAHARASHTRA           IN
# freq           109487   121180      11217        22260       128940
#
#                                        promotion-ids     B2B fulfilled-by  \
# count                                          79820  128973        39275
# unique                                          5787       2            1
# top     IN Core Free Shipping 2015/04/08 23-48-5-108   False    Easy Ship
# freq                                           46100  128102        39275
#
#        Unnamed: 22
# count        79923
# unique           1
# top          False
# freq         79923

# %%
report['Status'].value_counts().plot(kind='bar')
plt.xlabel('Status')
plt.ylabel('Frequency')
plt.title('Category Distribution')
plt.show()

# %%
data = report['Status'].value_counts(normalize=True)*100

plt.figure(figsize=(8, 8))
plt.pie(data.values.tolist(), labels=data.index.tolist())
plt.title('TODO')
plt.show()

# %%
report['Fulfilment'].value_counts().plot(kind='bar')
plt.xlabel('Fulfilment')
plt.ylabel('Frequency')
plt.title('Category Distribution')
plt.show()

# %%
report.isnull().sum()
# Out:
# index                     2
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       2
# Category                  2
# Size                      2
# ASIN                      2
# Courier Status         6874
# Qty                       2
# currency               7797
# Amount                 7797
# ship-city                35
# ship-state               37
# ship-postal-code         37
# ship-country             37
# promotion-ids         49157
# B2B                       4
# fulfilled-by          89702
# Unnamed: 22           49054
# dtype: int64

# %%
report.loc[report['index'].isnull()]
# Out:
#         index       Order ID      Date Status  \
# 69618     NaN  UTTAR PRADESH  226002.0     IN
# 128256    NaN  UTTAR PRADESH  226002.0     IN
#
#                                                Fulfilment Sales Channel   \
# 69618   Amazon PLCC Free-Financing Universal Merchant ...          False
# 128256  Amazon PLCC Free-Financing Universal Merchant ...          False
#
#        ship-service-level  Style  SKU Category  ... currency Amount ship-city  \
# 69618           Easy Ship  False  NaN      NaN  ...      NaN    NaN       NaN
# 128256          Easy Ship  False  NaN      NaN  ...      NaN    NaN       NaN
#
#         ship-state ship-postal-code  ship-country promotion-ids  B2B  \
# 69618          NaN              NaN           NaN           NaN  NaN
# 128256         NaN              NaN           NaN           NaN  NaN
#
#         fulfilled-by Unnamed: 22
# 69618            NaN         NaN
# 128256           NaN         NaN
#
# [2 rows x 24 columns]

# %%
report=report.dropna(subset=['index'])

# %%
report.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               35
# ship-postal-code         35
# ship-country             35
# promotion-ids         49155
# B2B                       2
# fulfilled-by          89700
# Unnamed: 22           49052
# dtype: int64

# %%
report.loc[report['Courier Status'].isnull()].describe(include=object)
# Out:
#                    Order ID      Date     Status Fulfilment Sales Channel   \
# count                  6872      6872       6872       6872           6872
# unique                 6393        91          3          1              1
# top     171-5057375-2831560  04-16-22  Cancelled   Merchant      Amazon.in
# freq                     12       137       6861       6872           6872
#
#        ship-service-level    Style           SKU Category  Size        ASIN  \
# count                6872     6872          6872     6872  6872        6872
# unique                  1      844          2587        8    11        2587
# top              Standard  JNE3797  JNE3797-KR-L      Set     M  B09SDXFFQ1
# freq                 6872      444           101     2624  1291         101
#
#        Courier Status currency  ship-city   ship-state ship-country  \
# count               0     5136       6869         6869         6869
# unique              0        1       1635           46            1
# top               NaN      INR  BENGALURU  MAHARASHTRA           IN
# freq              NaN     5136        424         1039         6869
#
#        promotion-ids    B2B fulfilled-by Unnamed: 22
# count              0   6872         6872        4057
# unique             0      2            1           1
# top              NaN  False    Easy Ship       False
# freq             NaN   6849         6872        4057

# %%
print("Courier status values when report status is cancelled: ",report.loc[report['Status']=="Cancelled"]["Courier Status"].unique())
report.loc[report['Status']=="Cancelled",'Courier Status'].describe(include=object)
# Out:
# Courier status values when report status is cancelled:  [nan 'Cancelled' 'Unshipped']
# count         11471
# unique            2
# top       Cancelled
# freq           5840
# Name: Courier Status, dtype: object

# %%
report.loc[report['Courier Status'].isnull() & (report['Status']!="Cancelled"),'Status']
# Out:
# 18894    Shipped - Delivered to Buyer
# 19292    Shipped - Delivered to Buyer
# 23873    Shipped - Delivered to Buyer
# 35337    Shipped - Delivered to Buyer
# 46852    Shipped - Delivered to Buyer
# 63344    Shipped - Delivered to Buyer
# 65174    Shipped - Delivered to Buyer
# 71444    Shipped - Returned to Seller
# 74297    Shipped - Returned to Seller
# 75252    Shipped - Delivered to Buyer
# 84212    Shipped - Returned to Seller
# Name: Status, dtype: object

# %%
report.loc[report['Status']=="Shipped - Delivered to Buyer",'Courier Status'].describe()
# Out:
# count       28761
# unique          1
# top       Shipped
# freq        28761
# Name: Courier Status, dtype: object

# %%
report.loc[report['Status']=="Shipped - Delivered to Seller",'Courier Status'].describe()
# Out:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: Courier Status, dtype: object

# %%
report.loc[report['Status']=="Shipped - Returned to Seller",'Courier Status'].describe()
# Out:
# count        1950
# unique          1
# top       Shipped
# freq         1950
# Name: Courier Status, dtype: object

# %%
m1 = report['Courier Status'].isnull() & (report['Status']=="Cancelled")
m2 = report['Courier Status'].isnull() &( (report['Status']=="Shipped - Delivered to Seller")| (report['Status']=="Shipped - Delivered to Buyer")| (report['Status']=="Shipped - Returned to Seller"))
report.loc[m1,"Courier Status"] = report.loc[m1,"Courier Status"].fillna("Cancelled")
report.loc[m2,"Courier Status"] = report.loc[m2,"Courier Status"].fillna("Shipped")

# %%
report.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status            0
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               35
# ship-postal-code         35
# ship-country             35
# promotion-ids         49155
# B2B                       2
# fulfilled-by          89700
# Unnamed: 22           49052
# dtype: int64

# %%
report.loc[report['Amount'].isnull()]
# Out:
#            index             Order ID      Date     Status Fulfilment  \
# 8            8.0  407-5443024-5233168  04-30-22  Cancelled     Amazon
# 29          29.0  404-5933402-8801952  04-30-22  Cancelled   Merchant
# 65          65.0  171-4137548-0481151  04-30-22  Cancelled     Amazon
# 84          84.0  403-9950518-0349133  04-30-22  Cancelled     Amazon
# 95          95.0  405-9112089-3379536  04-30-22  Cancelled     Amazon
# ...          ...                  ...       ...        ...        ...
# 128905  128903.0  406-3923120-4345139  05-31-22  Cancelled     Amazon
# 128909  128907.0  403-6757403-6097100  05-31-22  Cancelled     Amazon
# 128910  128908.0  403-6757403-6097100  05-31-22  Cancelled     Amazon
# 128960  128958.0  408-9513596-4393945  05-31-22  Cancelled     Amazon
# 128969  128967.0  404-5182288-1653947  05-31-22  Cancelled     Amazon
#
#        Sales Channel  ship-service-level    Style                  SKU  \
# 8           Amazon.in          Expedited   SET200  SET200-KR-NP-A-XXXL
# 29          Amazon.in           Standard  JNE2132  JNE2132-KR-398-XXXL
# 65          Amazon.in          Expedited  JNE3373       JNE3373-KR-XXL
# 84          Amazon.in          Expedited  JNE3510         JNE3510-KR-M
# 95          Amazon.in          Expedited  JNE3405         JNE3405-KR-L
# ...               ...                ...      ...                  ...
# 128905      Amazon.in          Expedited  JNE3801         JNE3801-KR-M
# 128909      Amazon.in          Expedited    NW014     NW014-ST-SR-XXXL
# 128910      Amazon.in          Expedited    NW007     NW007-ST-CP-XXXL
# 128960      Amazon.in          Expedited   SET058       SET058-KR-NP-L
# 128969      Amazon.in          Expedited  JNE3638        JNE3638-KR-XS
#
#        Category  ... currency Amount      ship-city      ship-state  \
# 8           Set  ...      NaN    NaN      HYDERABAD       TELANGANA
# 29        kurta  ...      NaN    NaN       GUWAHATI           ASSAM
# 65        kurta  ...      NaN    NaN          Dahod         Gujarat
# 84        kurta  ...      NaN    NaN      HYDERABAD       TELANGANA
# 95        kurta  ...      NaN    NaN           PUNE     MAHARASHTRA
# ...         ...  ...      ...    ...            ...             ...
# 128905    kurta  ...      NaN    NaN      ANANTAPUR  ANDHRA PRADESH
# 128909      Set  ...      NaN    NaN  GREATER NOIDA   UTTAR PRADESH
# 128910      Set  ...      NaN    NaN  GREATER NOIDA   UTTAR PRADESH
# 128960      Set  ...      NaN    NaN      Bengaluru       KARNATAKA
# 128969    kurta  ...      NaN    NaN        Kolkata     WEST BENGAL
#
#        ship-postal-code  ship-country  \
# 8              500008.0            IN
# 29             781003.0            IN
# 65             389151.0            IN
# 84             500072.0            IN
# 95             411046.0            IN
# ...                 ...           ...
# 128905         515001.0            IN
# 128909         201306.0            IN
# 128910         201306.0            IN
# 128960         560037.0            IN
# 128969         700040.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 8       IN Core Free Shipping 2015/04/08 23-48-5-108  False           NaN
# 29                                               NaN  False     Easy Ship
# 65                                               NaN  False           NaN
# 84                                               NaN  False           NaN
# 95                                               NaN  False           NaN
# ...                                              ...    ...           ...
# 128905                                           NaN  False           NaN
# 128909                                           NaN  False           NaN
# 128910                                           NaN  False           NaN
# 128960                                           NaN  False           NaN
# 128969                                           NaN  False           NaN
#
#        Unnamed: 22
# 8              NaN
# 29             NaN
# 65             NaN
# 84             NaN
# 95             NaN
# ...            ...
# 128905       False
# 128909       False
# 128910       False
# 128960       False
# 128969       False
#
# [7795 rows x 24 columns]

# %%
report['Amount']=report['Amount'].fillna(0)
report['currency']=report['currency'].fillna("INR")

# %%
report.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status            0
# Qty                       0
# currency                  0
# Amount                    0
# ship-city                33
# ship-state               35
# ship-postal-code         35
# ship-country             35
# promotion-ids         49155
# B2B                       2
# fulfilled-by          89700
# Unnamed: 22           49052
# dtype: int64

# %%
report.drop('Unnamed: 22', axis=1, inplace=True)

# %%
report['Date']=pd.to_datetime(report['Date'])
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_12764\4256239363.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   report['Date']=pd.to_datetime(report['Date'])

# %%
report.dtypes
# Out:
# index                        float64
# Order ID                      object
# Date                  datetime64[ns]
# Status                        object
# Fulfilment                    object
# Sales Channel                 object
# ship-service-level            object
# Style                         object
# SKU                           object
# Category                      object
# Size                          object
# ASIN                          object
# Courier Status                object
# Qty                          float64
# currency                      object
# Amount                       float64
# ship-city                     object
# ship-state                    object
# ship-postal-code             float64
# ship-country                  object
# promotion-ids                 object
# B2B                           object
# fulfilled-by                  object
# dtype: object

# %%
report['ship-postal-code']=report['ship-postal-code'].astype('category')
